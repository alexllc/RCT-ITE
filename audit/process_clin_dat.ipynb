# %% [markdown]
# # NCT00364013

# %%
import numpy as np
import pandas as pd
import glob
import re
import os

# %%
os.chdir("/home/alex/Documents/lab/RCT-ITE/dat/PDS/Colorec_Amgen_2006_309_NCT00364013/csv/")

adsl = pd.read_csv("adsl_pds2019.csv")
biomark = pd.read_csv("biomark_pds2019.csv")

NCT00364013_df = pd.merge(adsl, biomark, on = ["SUBJID", "SUBJID"], how = 'left')
print(NCT00364013_df)
adsl.head()
# Out:
#      SUBJID                   TRT                  ATRT PRSURG  DTHDY  DTH  \
# 0         1          FOLFOX alone          FOLFOX alone      Y    558    1
# 1         3  Panitumumab + FOLFOX  Panitumumab + FOLFOX      Y    301    1
# 2         4          FOLFOX alone          FOLFOX alone      Y    460    1
# 3         5          FOLFOX alone          FOLFOX alone      Y    965    1
# 4         6          FOLFOX alone          FOLFOX alone      N    211    1
# ..      ...                   ...                   ...    ...    ...  ...
# 930    1178          FOLFOX alone          FOLFOX alone      Y    528    1
# 931    1179          FOLFOX alone          FOLFOX alone      Y    363    1
# 932    1181  Panitumumab + FOLFOX  Panitumumab + FOLFOX      Y    672    1
# 933    1182  Panitumumab + FOLFOX  Panitumumab + FOLFOX      Y    684    1
# 934    1183          FOLFOX alone          FOLFOX alone      Y    770    1
#
# ...

# %% [markdown]
# # NCT00113763
